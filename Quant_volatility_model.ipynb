# %% [markdown]
# <a href="https://colab.research.google.com/github/Storm00212/A-Dataset-for-Automatic-Violence-Detection-in-Videos/blob/master/Quant_volatility_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from mpl_toolkits.mplot3d import Axes3D

# %%
np.random.seed(42)

T = 1200            # time points
mu = 0.0003         # drift
sigma = 0.012       # volatility

returns = mu + sigma * np.random.randn(T)
